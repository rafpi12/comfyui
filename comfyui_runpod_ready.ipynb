# %%
# !git clone https://github.com/comfyanonymous/ComfyUI.git /workspace/ComfyUI

# %%
# === INSTALLATION COMFYUI-MANAGER ===

import subprocess

print(">>> Installation de ComfyUI-Manager...")

subprocess.run("git clone https://github.com/Comfy-Org/ComfyUI-Manager /workspace/ComfyUI/custom_nodes/ComfyUI-Manager", shell=True)

# Installation des dépendances
subprocess.run("source /workspace/ComfyUI/venv/bin/activate && pip install -r /workspace/ComfyUI/custom_nodes/ComfyUI-Manager/requirements.txt", shell=True)

print("\n>>> ComfyUI-Manager installé.")
print(">>> Relance ComfyUI pour que le bouton 'Manager' apparaisse dans l'interface.")

# %%
# BASE DE DONNÉES COMPLÈTE (V6 - SCAN NUCLÉAIRE)
db_models_full = {
    "🦁 Wan 2.2 Core": [
        ("Wan 2.2 T2V High", "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/diffusion_models/wan2.2_t2v_high_noise_14B_fp8_scaled.safetensors?download=true", "workspace/ComfyUI/models/diffusion_models", "wan2.2_t2v_high_noise_14B_fp8_scaled.safetensors", "hf"),
        ("Wan 2.2 T2V Low", "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/diffusion_models/wan2.2_t2v_low_noise_14B_fp8_scaled.safetensors?download=true", "workspace/ComfyUI/models/diffusion_models", "wan2.2_t2v_low_noise_14B_fp8_scaled.safetensors", "hf"),
        ("Wan 2.2 Remix High", "https://huggingface.co/FX-FeiHou/wan2.2-Remix/resolve/main/NSFW/Wan2.2_Remix_NSFW_i2v_14b_high_lighting_v2.0.safetensors?download=true", "workspace/ComfyUI/models/diffusion_models", "Wan2.2_Remix_NSFW_i2v_14b_high_lighting_v2.0.safetensors", "hf"),
        ("Wan 2.2 Remix Low", "https://huggingface.co/FX-FeiHou/wan2.2-Remix/resolve/main/NSFW/Wan2.2_Remix_NSFW_i2v_14b_low_lighting_v2.0.safetensors?download=true", "workspace/ComfyUI/models/diffusion_models", "Wan2.2_Remix_NSFW_i2v_14b_low_lighting_v2.0.safetensors", "hf"),
        ("Wan VAE 2.2", "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/vae/wan2.2_vae.safetensors?download=true", "workspace/ComfyUI/models/vae", "wan2.2_vae.safetensors", "hf"),
        ("Wan VAE 2.1", "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_Repackaged/resolve/main/vae/wan_2.1_vae.safetensors?download=true", "workspace/ComfyUI/models/vae", "wan_2.1_vae.safetensors", "hf"),
        ("Wan VAE Upscale", "https://huggingface.co/spacepxl/Wan2.1-VAE-upscale2x/resolve/main/Wan2.1_VAE_upscale2x_imageonly_real_v1.safetensors?download=true", "workspace/ComfyUI/models/vae", "Wan2.1_VAE_upscale2x_imageonly_real_v1.safetensors", "hf"),
        ("UMT5 XXL", "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_Repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true", "workspace/ComfyUI/models/text_encoders", "umt5_xxl_fp8_e4m3fn_scaled.safetensors", "hf"),
        ("Wan NSFW Enc", "https://huggingface.co/NSFW-API/NSFW-Wan-UMT5-XXL/resolve/main/nsfw_wan_umt5-xxl_fp8_scaled.safetensors?download=true", "workspace/ComfyUI/models/clip", "nsfw_wan_umt5_xxl_fp8_scaled.safetensors", "hf"),
    ],
    "⚡ Wan LoRAs": [
        ("Lightning I2V High", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-I2V-A14B-4steps-lora-rank64-Seko-V1.1/high_noise_model.safetensors?download=true", "workspace/ComfyUI/models/loras/Wan", "Wan2.2-Lightning_I2V-A14B-4steps-lora_HIGH_fp16.safetensors", "hf"),
        ("Lightning I2V Low", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-I2V-A14B-4steps-lora-rank64-Seko-V1.1/low_noise_model.safetensors?download=true", "workspace/ComfyUI/models/loras/Wan", "Wan2.2-Lightning_I2V-A14B-4steps-lora_LOW_fp16.safetensors", "hf"),
        ("Lightning T2V High", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-T2V-A14B-4steps-lora-rank64-Seko-V1.1/high_noise_model.safetensors?download=true", "workspace/ComfyUI/models/loras/Wan", "Wan22_A14B_T2V_HIGH_Lightning_4steps_lora_250928_rank128_fp16.safetensors", "hf"),
        ("Lightning T2V Low", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-T2V-A14B-4steps-lora-rank64-Seko-V1.1/low_noise_model.safetensors?download=true", "workspace/ComfyUI/models/loras/Wan", "Wan22_A14B_T2V_LOW_Lightning_4steps_lora_250928_rank64_fp16.safetensors", "hf"),
        ("Orbit High", "https://huggingface.co/ostris/wan22_i2v_14b_orbit_shot_lora/resolve/main/wan22_14b_i2v_orbit_high_noise.safetensors?download=true", "workspace/ComfyUI/models/loras", "wan22_14b_i2v_orbit_high_noise.safetensors", "hf"),
        ("Orbit Low", "https://huggingface.co/ostris/wan22_i2v_14b_orbit_shot_lora/resolve/main/wan22_14b_i2v_orbit_low_noise.safetensors?download=true", "workspace/ComfyUI/models/loras", "wan22_14b_i2v_orbit_low_noise.safetensors", "hf"),
        ("Smartphone Photo V5", "https://civitai.com/api/download/models/2079658?type=Model&format=SafeTensor", "workspace/ComfyUI/models/loras/Wan", "WAN2.2_SmartphoneSnapshotPhotoReality_v5_by-AI_Characters_TRIGGER$amateur photo$_low_noise.safetensors", "civitai"),
    ],
    "🐲 Qwen Core & LoRAs": [
        ("Qwen Image BF16", "https://huggingface.co/Comfy-Org/Qwen2.5-VL-ComfyUI-Repackaged/resolve/main/qwen_image_bf16.safetensors?download=true", "workspace/ComfyUI/models/diffusion_models", "qwen_image_bf16.safetensors", "hf"),
        ("Qwen Edit Model", "https://huggingface.co/aidiffuser/Qwen-Image-Edit-2509/resolve/main/Qwen-Image-Edit-2509_fp8_e4m3fn.safetensors?download=true", "workspace/ComfyUI/models/diffusion_models", "Qwen-Image-Edit-2509_fp8_e4m3fn.safetensors", "hf"),
        ("Qwen VAE", "https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/vae/qwen_image_vae.safetensors", "workspace/ComfyUI/models/vae", "qwen_image_vae.safetensors", "hf"),
        ("Qwen CLIP", "https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/text_encoders/qwen_2.5_vl_7b.safetensors", "workspace/ComfyUI/models/text_encoders", "qwen_2.5_vl_7b.safetensors", "hf"),
        ("Qwen Lightning V2", "https://huggingface.co/lightx2v/Qwen-Image-Lightning/resolve/main/Qwen-Image-Lightning-8steps-V2.0-bf16.safetensors?download=true", "workspace/ComfyUI/models/loras/QWEN", "Qwen-Image-Lightning-8steps-V2.0-bf16.safetensors", "hf"),
        ("Qwen Edit Lightning", "https://huggingface.co/lightx2v/Qwen-Image-Lightning/resolve/main/Qwen-Image-Edit-Lightning-8steps-V1.0-bf16.safetensors?download=true", "workspace/ComfyUI/models/loras/QWEN", "Qwen-Image-Edit-Lightning-8steps-V1.0-bf16.safetensors", "hf"),
        ("Famegrid SkinFix", "https://civitai.com/api/download/models/2453097?type=Model&format=SafeTensor", "workspace/ComfyUI/models/loras/QWEN", "Famegrid_Qwen_Lora_Standard_V1.5_RealSkinFix.safetensors", "civitai"),
        ("1Girl Qwen", "https://huggingface.co/dci05049/qwen/resolve/main/1girl-qwen_v3.safetensors", "workspace/ComfyUI/models/loras/QWEN", "1girl-qwen_v3.safetensors", "hf"),
    ],
    "🌊 Flux & Autres LoRAs": [
        ("Flux Krea FP8", "https://civitai.com/api/download/models/2079678?type=Model&format=SafeTensor&size=pruned&fp=fp8", "workspace/ComfyUI/models/unet", "flux1KreaDevFP8_fp8SCALED.safetensors", "civitai"),
        ("Pulid Flux", "https://huggingface.co/guozinan/PuLID/resolve/main/pulid_flux_v0.9.0.safetensors?download=true", "workspace/ComfyUI/models/pulid", "pulid_flux_v0.9.0.safetensors", "hf"),
        ("FC Flux Busts", "https://civitai.com/api/download/models/788523?type=Model&format=SafeTensor", "workspace/ComfyUI/models/loras", "FC Flux Perfect Busts.safetensors", "civitai"),
        ("TKTT SteepSlope", "https://civitai.com/api/download/models/746019?type=Model&format=SafeTensor", "workspace/ComfyUI/models/loras", "TKTT_SteepSlopeTiddiesXXL_FLUX.safetensors", "civitai"),
        ("Vyesna v4", "METTRE_URL_PRIVEE_ICI", "workspace/ComfyUI/models/loras", "Vyesna_v4.safetensors", "civitai"),
        ("Olivia 2025", "METTRE_URL_PRIVEE_ICI", "workspace/ComfyUI/models/loras", "olivia2025.safetensors", "civitai"),
    ],
    "🛠️ Outils & Restore": [
        ("CodeFormer", "https://github.com/sczhou/CodeFormer/releases/download/v0.1.0/codeformer-v0.1.0.pth", "workspace/ComfyUI/models/facerestore_models", "codeformer-v0.1.0.pth", "hf"),
        ("GFPGAN 1.4", "https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.4.pth", "workspace/ComfyUI/models/facerestore_models", "GFPGANv1.4.pth", "hf"),
        ("4x UltraSharp", "https://huggingface.co/lokCX/4x-Ultrasharp/resolve/main/4x-UltraSharp.pth", "workspace/ComfyUI/models/upscale_models", "4x-UltraSharp.pth", "hf"),
        ("Face Parse Bisenet", "https://huggingface.co/leonelhs/bisenet-face-parsing/resolve/main/parsing_bisenet.pth", "workspace/ComfyUI/models/facexlib", "parsing_bisenet.pth", "hf"),
        ("Detection Resnet50", "https://huggingface.co/leonelhs/bisenet-face-parsing/resolve/main/detection_Resnet50_Final.pth", "workspace/ComfyUI/models/facexlib", "detection_Resnet50_Final.pth", "hf"),
        ("Insightface AntelopeV2", "https://huggingface.co/okaris/antelopev2/resolve/main/1k3d68.onnx", "workspace/ComfyUI/models/insightface/models/antelopev2", "1k3d68.onnx", "hf"), # + les 4 autres fichiers
    ]
}

# %%
# WAN 2.2 FILES DOWNLOAD

import os
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- 1. CONFIGURATION SÉCURISÉE (Plus de tokens en clair) ---
CIVITAI_TOKEN = os.environ.get("CIVITAI_TOKEN", "")
HF_TOKEN = os.environ.get("HF_TOKEN", "")

# Installation silencieuse de aria2
os.system("apt-get update -y > /dev/null && apt-get install -y aria2 > /dev/null")

# --- 2. BASE DE DONNÉES (Chemins Absolus) ---
db_models = {
    "🦁 Wan 2.2 Core & Dépendances": [
        ("[13.6 GB] Wan 2.2 T2V High (14B)", "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/diffusion_models/wan2.2_t2v_high_noise_14B_fp8_scaled.safetensors?download=true", "/workspace/ComfyUI/models/diffusion_models", "wan2.2_t2v_high_noise_14B_fp8_scaled.safetensors", "hf"),
        ("[13.6 GB] Wan 2.2 T2V Low (14B)", "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/diffusion_models/wan2.2_t2v_low_noise_14B_fp8_scaled.safetensors?download=true", "/workspace/ComfyUI/models/diffusion_models", "wan2.2_t2v_low_noise_14B_fp8_scaled.safetensors", "hf"),
        ("[13.6 GB] Wan 2.2 Remix High (NSFW)", "https://huggingface.co/FX-FeiHou/wan2.2-Remix/resolve/main/NSFW/Wan2.2_Remix_NSFW_i2v_14b_high_lighting_v2.0.safetensors?download=true", "/workspace/ComfyUI/models/diffusion_models", "Wan2.2_Remix_NSFW_i2v_14b_high_lighting_v2.0.safetensors", "hf"),
        ("[13.6 GB] Wan 2.2 Remix Low (NSFW)", "https://huggingface.co/FX-FeiHou/wan2.2-Remix/resolve/main/NSFW/Wan2.2_Remix_NSFW_i2v_14b_low_lighting_v2.0.safetensors?download=true", "/workspace/ComfyUI/models/diffusion_models", "Wan2.2_Remix_NSFW_i2v_14b_low_lighting_v2.0.safetensors", "hf"),
        ("[1.3 GB] Wan VAE 2.2 (Standard)", "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/vae/wan2.2_vae.safetensors?download=true", "/workspace/ComfyUI/models/vae", "wan2.2_vae.safetensors", "hf"),
        ("[242 MB] Wan VAE 2.1 (Compatible)", "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors?download=true", "/workspace/ComfyUI/models/vae", "wan_2.1_vae.safetensors", "hf"),
        ("[484 MB] Wan VAE Upscale (2x)", "https://huggingface.co/spacepxl/Wan2.1-VAE-upscale2x/resolve/main/Wan2.1_VAE_upscale2x_imageonly_real_v1.safetensors?download=true", "/workspace/ComfyUI/models/vae", "Wan2.1_VAE_upscale2x_imageonly_real_v1.safetensors", "hf"),
        ("[6.3 GB] Text Encoder UMT5 XXL", "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_Repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors?download=true", "/workspace/ComfyUI/models/text_encoders", "umt5_xxl_fp8_e4m3fn_scaled.safetensors", "hf"),
        ("[6.3 GB] Wan NSFW Text Enc Helper", "https://huggingface.co/NSFW-API/NSFW-Wan-UMT5-XXL/resolve/main/nsfw_wan_umt5-xxl_fp8_scaled.safetensors?download=true", "/workspace/ComfyUI/models/clip", "nsfw_wan_umt5_xxl_fp8_scaled.safetensors", "hf"),
    ],
    "⚡ Wan LoRAs (Lightning & Styles)": [
        ("[585 MB] Lightning I2V High", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-I2V-A14B-4steps-lora-rank64-Seko-V1.1/high_noise_model.safetensors?download=true", "/workspace/ComfyUI/models/loras/Wan", "Wan2.2-Lightning_I2V-A14B-4steps-lora_HIGH_fp16.safetensors", "hf"),
        ("[585 MB] Lightning I2V Low", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-I2V-A14B-4steps-lora-rank64-Seko-V1.1/low_noise_model.safetensors?download=true", "/workspace/ComfyUI/models/loras/Wan", "Wan2.2-Lightning_I2V-A14B-4steps-lora_LOW_fp16.safetensors", "hf"),
        ("[585 MB] Lightning T2V High", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-T2V-A14B-4steps-lora-rank64-Seko-V1.1/high_noise_model.safetensors?download=true", "/workspace/ComfyUI/models/loras/Wan", "Wan22_A14B_T2V_HIGH_Lightning_4steps_lora_250928_rank128_fp16.safetensors", "hf"),
        ("[585 MB] Lightning T2V Low", "https://huggingface.co/lightx2v/Wan2.2-Lightning/resolve/main/Wan2.2-T2V-A14B-4steps-lora-rank64-Seko-V1.1/low_noise_model.safetensors?download=true", "/workspace/ComfyUI/models/loras/Wan", "Wan22_A14B_T2V_LOW_Lightning_4steps_lora_250928_rank64_fp16.safetensors", "hf"),
        ("[146 MB] Orbit High (Ostris)", "https://huggingface.co/ostris/wan22_i2v_14b_orbit_shot_lora/resolve/main/wan22_14b_i2v_orbit_high_noise.safetensors?download=true", "/workspace/ComfyUI/models/loras", "wan22_14b_i2v_orbit_high_noise.safetensors", "hf"),
        ("[146 MB] Orbit Low (Ostris)", "https://huggingface.co/ostris/wan22_i2v_14b_orbit_shot_lora/resolve/main/wan22_14b_i2v_orbit_low_noise.safetensors?download=true", "/workspace/ComfyUI/models/loras", "wan22_14b_i2v_orbit_low_noise.safetensors", "hf"),
        ("[73 MB] Smartphone Photo V5", "https://civitai.com/api/download/models/2079658?type=Model&format=SafeTensor", "/workspace/ComfyUI/models/loras/Wan", "WAN2.2_SmartphoneSnapshotPhotoReality_v5_by-AI_Characters_TRIGGER$amateur photo$_low_noise.safetensors", "civitai"),
    ]
}

# --- 3. INTERFACE GRAPHIQUE ---
style = {'description_width': 'initial'}
layout = widgets.Layout(width='98%')
checkboxes = {}
output_log = widgets.Output(layout={'border': '1px solid #444', 'height': '250px', 'overflow_y': 'scroll'})

accordion_children = []
titles = []

for category, items in db_models.items():
    vbox_items = []
    select_all = widgets.Button(description="Tout cocher", icon="check-square-o", button_style='info', layout=widgets.Layout(width='150px'))
    def on_select_all(b, cat=category):
        for k, val in checkboxes.items():
            if k.startswith(cat):
                val['cb'].value = True
    select_all.on_click(on_select_all)
    vbox_items.append(select_all)
    
    for item in items:
        name, url, path, filename, src = item
        key = f"{category}|{filename}"
        label = f"{name}"
        cb = widgets.Checkbox(value=False, description=label, style=style, layout=layout)
        checkboxes[key] = {'cb': cb, 'data': item}
        vbox_items.append(cb)
        
    accordion_children.append(widgets.VBox(vbox_items))
    titles.append(category)

accordion = widgets.Accordion(children=accordion_children)
for i, title in enumerate(titles):
    accordion.set_title(i, title)
    accordion.selected_index = 0

btn_download = widgets.Button(
    description='LANCER LE TÉLÉCHARGEMENT (Mode Éco)',
    button_style='success', 
    layout=widgets.Layout(width='100%', height='60px', margin='20px 0px 0px 0px'),
    icon='download'
)

# --- 4. LOGIQUE DE TÉLÉCHARGEMENT (PROTECTION DATA) ---
def run_download(b):
    output_log.clear_output()
    with output_log:
        print("🚀 Traitement des fichiers demandés...\n")
        count = 0
        for key, val in checkboxes.items():
            if val['cb'].value:
                count += 1
                item = val['data']
                name, url, path, filename, src = item
                
                os.makedirs(path, exist_ok=True)
                full_path = os.path.join(path, filename)
                
                # Check anti-overwrite
                if os.path.exists(full_path) and os.path.getsize(full_path) > 1024:
                    print(f"⏩ [SKIP] {name} est déjà là. (0 data utilisée)")
                    continue

                if "METTRE_URL" in url:
                    print(f"⚠️ [SKIP] URL manquante pour {name}.")
                    continue

                auth = ""
                final_url = url
                if src == "hf":
                    auth = f'--header="Authorization: Bearer {HF_TOKEN}"'
                elif src == "civitai":
                    sep = "&" if "?" in url else "?"
                    final_url = f"{url}{sep}token={CIVITAI_TOKEN}"
                
                print(f"⬇️ Téléchargement de : {name}")
                cmd = f'aria2c -x 16 -s 16 -k 1M -c {auth} -d "{path}" -o "{filename}" "{final_url}"'
                ret = os.system(cmd)
                if ret == 0: print(f"   ✅ OK.")
                else: print(f"   ⚠️ Erreur (Code {ret}).")
                    
        if count == 0: print("⚠️ Aucune case cochée.")
        else: print("\n🎉 Terminé.")

btn_download.on_click(run_download)

display(widgets.VBox([
    widgets.Label("🦁 INSTALLATION WAN 2.2 (Avec Tailles)"),
    accordion,
    btn_download,
    output_log
]))

# %%
# QWEN FILES DOWNLOAD

import os
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- 1. CONFIGURATION SÉCURISÉE ---
CIVITAI_TOKEN = os.environ.get("CIVITAI_TOKEN", "")
HF_TOKEN = os.environ.get("HF_TOKEN", "")

# Installation silencieuse de aria2
os.system("apt-get update -y > /dev/null && apt-get install -y aria2 > /dev/null")

# --- 2. BASE DE DONNÉES (Avec Tailles) ---
db_models = {
    "🐲 Qwen Core (Image & Edit)": [
        ("[38.1 GB] Qwen Image BF16", "https://huggingface.co/Comfy-Org/Qwen2.5-VL-ComfyUI-Repackaged/resolve/main/qwen_image_bf16.safetensors?download=true", "/workspace/ComfyUI/models/diffusion_models", "qwen_image_bf16.safetensors", "hf"),
        ("[19.0 GB] Qwen Edit Model (FP8)", "https://huggingface.co/aidiffuser/Qwen-Image-Edit-2509/resolve/main/Qwen-Image-Edit-2509_fp8_e4m3fn.safetensors?download=true", "/workspace/ComfyUI/models/diffusion_models", "Qwen-Image-Edit-2509_fp8_e4m3fn.safetensors", "hf"),
        ("[242 MB] Qwen VAE", "https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/vae/qwen_image_vae.safetensors", "/workspace/ComfyUI/models/vae", "qwen_image_vae.safetensors", "hf"),
        ("[15.4 GB] Qwen CLIP (VL 7B)", "https://huggingface.co/Comfy-Org/Qwen-Image_ComfyUI/resolve/main/split_files/text_encoders/qwen_2.5_vl_7b.safetensors", "/workspace/ComfyUI/models/text_encoders", "qwen_2.5_vl_7b.safetensors", "hf"),
    ],
    "🎨 Qwen LoRAs (Noms Complets)": [
        ("[1.6 GB] Qwen-Image-Lightning-8steps-V2.0-bf16", "https://huggingface.co/lightx2v/Qwen-Image-Lightning/resolve/main/Qwen-Image-Lightning-8steps-V2.0-bf16.safetensors?download=true", "/workspace/ComfyUI/models/loras/QWEN", "Qwen-Image-Lightning-8steps-V2.0-bf16.safetensors", "hf"),
        ("[810 MB] Qwen-Image-Edit-Lightning-8steps-V1.0-bf16", "https://huggingface.co/lightx2v/Qwen-Image-Lightning/resolve/main/Qwen-Image-Edit-Lightning-8steps-V1.0-bf16.safetensors?download=true", "/workspace/ComfyUI/models/loras/QWEN", "Qwen-Image-Edit-Lightning-8steps-V1.0-bf16.safetensors", "hf"),
        ("[1.1 GB] Famegrid SkinFix (Civitai)", "https://civitai.com/api/download/models/2453097?type=Model&format=SafeTensor", "/workspace/ComfyUI/models/loras/QWEN", "Famegrid_Qwen_Lora_Standard_V1.5_RealSkinFix.safetensors", "civitai"),
        ("[2.2 GB] 1Girl Qwen Concept", "https://huggingface.co/dci05049/qwen/resolve/main/1girl-qwen_v3.safetensors", "/workspace/ComfyUI/models/loras/QWEN", "1girl-qwen_v3.safetensors", "hf"),
    ]
}

# --- 3. INTERFACE GRAPHIQUE ---
style = {'description_width': 'initial'}
layout = widgets.Layout(width='98%')
checkboxes = {}
output_log = widgets.Output(layout={'border': '1px solid #444', 'height': '200px', 'overflow_y': 'scroll'})

accordion_children = []
titles = []

for category, items in db_models.items():
    vbox_items = []
    select_all = widgets.Button(description="Tout cocher", icon="check-square-o", button_style='info', layout=widgets.Layout(width='150px'))
    def on_select_all(b, cat=category):
        for k, val in checkboxes.items():
            if k.startswith(cat):
                val['cb'].value = True
    select_all.on_click(on_select_all)
    vbox_items.append(select_all)
    
    for item in items:
        name, url, path, filename, src = item
        key = f"{category}|{filename}"
        label = f"{name}"
        cb = widgets.Checkbox(value=False, description=label, style=style, layout=layout)
        checkboxes[key] = {'cb': cb, 'data': item}
        vbox_items.append(cb)
        
    accordion_children.append(widgets.VBox(vbox_items))
    titles.append(category)

accordion = widgets.Accordion(children=accordion_children)
for i, title in enumerate(titles):
    accordion.set_title(i, title)
    accordion.selected_index = 0

btn_download = widgets.Button(
    description='LANCER LE TÉLÉCHARGEMENT (Qwen)',
    button_style='success', 
    layout=widgets.Layout(width='100%', height='60px', margin='20px 0px 0px 0px'),
    icon='download'
)

# --- 4. LOGIQUE DE TÉLÉCHARGEMENT ---
def run_download(b):
    output_log.clear_output()
    with output_log:
        print("🚀 Traitement des fichiers Qwen...\n")
        count = 0
        for key, val in checkboxes.items():
            if val['cb'].value:
                count += 1
                item = val['data']
                name, url, path, filename, src = item
                
                os.makedirs(path, exist_ok=True)
                full_path = os.path.join(path, filename)
                
                if os.path.exists(full_path) and os.path.getsize(full_path) > 1024:
                    print(f"⏩ [SKIP] {name} est déjà là. (0 data utilisée)")
                    continue

                auth = ""
                final_url = url
                if src == "hf":
                    auth = f'--header="Authorization: Bearer {HF_TOKEN}"'
                elif src == "civitai":
                    sep = "&" if "?" in url else "?"
                    final_url = f"{url}{sep}token={CIVITAI_TOKEN}"
                
                print(f"⬇️ Téléchargement de : {name}")
                cmd = f'aria2c -x 16 -s 16 -k 1M -c {auth} -d "{path}" -o "{filename}" "{final_url}"'
                ret = os.system(cmd)
                if ret == 0: print(f"   ✅ OK.")
                else: print(f"   ⚠️ Erreur (Code {ret}).")
                    
        if count == 0: print("⚠️ Aucune case cochée.")
        else: print("\n🎉 Terminé.")

btn_download.on_click(run_download)

display(widgets.VBox([
    widgets.Label("🐲 INSTALLATION QWEN 2.5 (Avec Tailles)"),
    accordion,
    btn_download,
    output_log
]))

# %%
# FLUX FILES DOWNLOAD

import os
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- 1. CONFIGURATION SÉCURISÉE ---
CIVITAI_TOKEN = os.environ.get("CIVITAI_TOKEN", "")
HF_TOKEN = os.environ.get("HF_TOKEN", "")

# Installation silencieuse de aria2
os.system("apt-get update -y > /dev/null && apt-get install -y aria2 > /dev/null")

# --- 2. BASE DE DONNÉES (Flux Core & LoRAs - Chemins Absolus) ---
db_models = {
    "🌊 Flux Core (UNET & Checkpoints)": [
        ("Flux.1 Krea Dev (FP8 Scaled)", "https://civitai.com/api/download/models/2079678?type=Model&format=SafeTensor&size=pruned&fp=fp8", "/workspace/ComfyUI/models/unet", "flux1KreaDevFP8_fp8SCALED.safetensors", "civitai"),
        ("Flux.1 Dev Officiel (FP8)", "https://huggingface.co/Comfy-Org/FLUX.1-dev-ComfyUI-Repackaged/resolve/main/flux1-dev-fp8.safetensors?download=true", "/workspace/ComfyUI/models/unet", "flux1-dev-fp8.safetensors", "hf"),
    ],
    "⚙️ Flux Dépendances (VAE & CLIP)": [
        ("VAE Flux (ae.safetensors)", "https://huggingface.co/black-forest-labs/FLUX.1-schnell/resolve/main/ae.safetensors?download=true", "/workspace/ComfyUI/models/vae", "ae.safetensors", "hf"),
        ("T5 XXL (FP8) - Encodeur Texte", "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp8_e4m3fn.safetensors?download=true", "/workspace/ComfyUI/models/clip", "t5xxl_fp8_e4m3fn.safetensors", "hf"),
        ("CLIP L - Encodeur Texte", "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/clip_l.safetensors?download=true", "/workspace/ComfyUI/models/clip", "clip_l.safetensors", "hf"),
    ],
    "💄 Flux LoRAs (Body & Styles)": [
        ("FC Flux Perfect Busts", "https://civitai.com/api/download/models/788523?type=Model&format=SafeTensor", "/workspace/ComfyUI/models/loras", "FC Flux Perfect Busts.safetensors", "civitai"),
        ("TKTT Steep Slope Tiddies XXL", "https://civitai.com/api/download/models/746019?type=Model&format=SafeTensor", "/workspace/ComfyUI/models/loras", "TKTT_SteepSlopeTiddiesXXL_FLUX.safetensors", "civitai"),
        ("Venus Body (Thicc)", "https://civitai.com/api/download/models/2244224?type=Model&format=SafeTensor", "/workspace/ComfyUI/models/loras", "venus_body_thicc.safetensors", "civitai"),
        ("Olivia 2025 (Fichier Privé/Local)", "METTRE_URL_ICI_SI_DISPO", "/workspace/ComfyUI/models/loras", "olivia2025.safetensors", "civitai"),
    ]
}

# --- 3. INTERFACE GRAPHIQUE ---
style = {'description_width': 'initial'}
layout = widgets.Layout(width='98%')
checkboxes = {}
output_log = widgets.Output(layout={'border': '1px solid #444', 'height': '200px', 'overflow_y': 'scroll'})

accordion_children = []
titles = []

for category, items in db_models.items():
    vbox_items = []
    select_all = widgets.Button(description="Tout cocher", icon="check-square-o", button_style='info', layout=widgets.Layout(width='150px'))
    def on_select_all(b, cat=category):
        for k, val in checkboxes.items():
            if k.startswith(cat):
                val['cb'].value = True
    select_all.on_click(on_select_all)
    vbox_items.append(select_all)
    
    for item in items:
        name, url, path, filename, src = item
        key = f"{category}|{filename}"
        label = f"{name}"
        cb = widgets.Checkbox(value=False, description=label, style=style, layout=layout)
        checkboxes[key] = {'cb': cb, 'data': item}
        vbox_items.append(cb)
        
    accordion_children.append(widgets.VBox(vbox_items))
    titles.append(category)

accordion = widgets.Accordion(children=accordion_children)
for i, title in enumerate(titles):
    accordion.set_title(i, title)
    accordion.selected_index = 0

btn_download = widgets.Button(
    description='LANCER LE TÉLÉCHARGEMENT (Flux)',
    button_style='success', 
    layout=widgets.Layout(width='100%', height='60px', margin='20px 0px 0px 0px'),
    icon='download'
)

# --- 4. LOGIQUE DE TÉLÉCHARGEMENT ---
def run_download(b):
    output_log.clear_output()
    with output_log:
        print("🚀 Traitement des fichiers Flux...\n")
        count = 0
        for key, val in checkboxes.items():
            if val['cb'].value:
                count += 1
                item = val['data']
                name, url, path, filename, src = item
                
                os.makedirs(path, exist_ok=True)
                full_path = os.path.join(path, filename)
                
                if os.path.exists(full_path) and os.path.getsize(full_path) > 1024:
                    print(f"⏩ [SKIP] {name} est déjà là. (0 data utilisée)")
                    continue
                
                if "METTRE_URL" in url:
                    print(f"⚠️ [SKIP] Pas d'URL fournie pour {name}.")
                    continue

                auth = ""
                final_url = url
                if src == "hf":
                    auth = f'--header="Authorization: Bearer {HF_TOKEN}"'
                elif src == "civitai":
                    sep = "&" if "?" in url else "?"
                    final_url = f"{url}{sep}token={CIVITAI_TOKEN}"
                
                print(f"⬇️ Téléchargement de : {name}")
                cmd = f'aria2c -x 16 -s 16 -k 1M -c {auth} -d "{path}" -o "{filename}" "{final_url}"'
                ret = os.system(cmd)
                if ret == 0: print(f"   ✅ OK.")
                else: print(f"   ⚠️ Erreur (Code {ret}).")
                    
        if count == 0: print("⚠️ Aucune case cochée.")
        else: print("\n🎉 Terminé.")

btn_download.on_click(run_download)

display(widgets.VBox([
    widgets.Label("🌊 INSTALLATION FLUX.1 (Core & LoRAs)"),
    accordion,
    btn_download,
    output_log
]))

# %%
# DISABLE REACTOR NSFW FILTER

import os

# Le chemin exact indiqué dans le guide (reactor_sfw.py)
target_path = "/workspace/ComfyUI/custom_nodes/comfyui-reactor/scripts/reactor_sfw.py"

# Le code patché (Nettoyé des commentaires qui cassaient la syntaxe)
bypass_code = """
from PIL import Image
import logging
import os
# On garde les imports essentiels pour éviter que ReActor ne plante au démarrage
from scripts.reactor_logger import logger

# On déclare que le modèle existe pour empêcher le téléchargement
MODEL_EXISTS = True

def ensure_nsfw_model(nsfwdet_model_path):
    # On ment au système : "Oui, le modèle est là, tout va bien"
    return True

def nsfw_image(img_data, model_path: str):
    # C'est ici que le bypass agit.
    # False = "Ce n'est pas NSFW" (Safe)
    # On renvoie False systématiquement sans même regarder l'image.
    return False
"""

print(f"🔧 Application du patch sur : {target_path}")

# Vérification d'existence du dossier
folder = os.path.dirname(target_path)
if os.path.exists(folder):
    try:
        with open(target_path, "w") as f:
            f.write(bypass_code)
        print("✅ Fichier 'reactor_sfw.py' écrasé avec succès.")
        print("🔓 Le filtre NSFW est maintenant désactivé.")
    except Exception as e:
        print(f"❌ Erreur lors de l'écriture : {e}")
else:
    print(f"❌ Le dossier {folder} n'existe pas. Vérifie l'installation de ReActor.")

# Par sécurité, on patche aussi l'ancien nom de fichier s'il existe (certaines versions varient)
alt_path = "/workspace/ComfyUI/custom_nodes/comfyui-reactor/scripts/reactor_nsfw.py"
if os.path.exists(alt_path):
    with open(alt_path, "w") as f:
        f.write(bypass_code)
    print("✅ Ancien fichier 'reactor_nsfw.py' également patché par sécurité.")

print("\n🚨 IMPORTANT : Tu dois REDÉMARRER ComfyUI (Stop/Start) pour que ce changement prenne effet !")

# %%
# FIX WAN 2.2 COLOR MATCHER NODE

import subprocess
import sys

# Installation de la librairie manquante 'color-matcher'
def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

try:
    print("⬇️ Installation de color-matcher en cours...")
    install("color-matcher")
    print("✅ Installation réussie ! Vous pouvez relancer ComfyUI.")
except Exception as e:
    print(f"❌ Erreur lors de l'installation : {e}")

# %%
# ComfyUI Launch Qwen or Wan 2.2

QWEN 
python main.py --listen 0.0.0.0 --port 8188 --disable-auto-launch --cache-ram 8 --bf16-unet

WAN2.2 
python main.py --listen 0.0.0.0 --port 8188 --disable-auto-launch --fast

# %%
# Démarrage de ComfyUI

import os
import shutil
import configparser
import re
import subprocess
import time

# --- CONFIGURATION ---
COMFY_DIR = "/workspace/ComfyUI"
CUSTOM_NODES = f"{COMFY_DIR}/custom_nodes"
PULID_DIR = f"{CUSTOM_NODES}/ComfyUI_PuLID_Flux_ll"
MANAGER_DIR = f"{CUSTOM_NODES}/ComfyUI-Manager"

print("🚀 DÉMARRAGE DU SCRIPT TOUT-EN-UN (Installation & Réparation)...")

# --- 1. DÉVERROUILLAGE DU MANAGER ---
print("\n🔓 [1/6] Déverrouillage du Manager...")
config_paths = [
    f"{COMFY_DIR}/user/default/ComfyUI-Manager/config.ini",
    f"{MANAGER_DIR}/config.ini"
]
for path in config_paths:
    if not os.path.exists(os.path.dirname(path)):
        os.makedirs(os.path.dirname(path), exist_ok=True)
    config = configparser.ConfigParser()
    if os.path.exists(path): config.read(path)
    if 'default' not in config: config['default'] = {}
    config['default']['security_level'] = 'weak'
    with open(path, 'w') as f: config.write(f)

# --- 2. INSTALLATION SYSTÈME ---
print("\n🔧 [2/6] Installation outils système (ffmpeg, aria2)...")
subprocess.run(["apt-get", "update"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
subprocess.run(["apt-get", "install", "-y", "ffmpeg", "aria2"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# --- 3. DÉPENDANCES PYTHON (La partie critique) ---
print("\n📦 [3/6] Installation des librairies Python...")
# Nettoyage préventif
subprocess.run(["pip", "uninstall", "-y", "xformers", "torch", "torchvision", "torchaudio", "huggingface_hub", "transformers", "diffusers", "insightface"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# PyTorch Stable
print("   -> PyTorch...")
subprocess.run(["pip", "install", "torch==2.5.1+cu124", "torchvision==0.20.1+cu124", "torchaudio==2.5.1+cu124", "--index-url", "https://download.pytorch.org/whl/cu124"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Stack InsightFace & PuLID & Bases
print("   -> Dépendances ComfyUI & PuLID...")
subprocess.run(["pip", "install", "--upgrade", "opencv-python", "GitPython", "scikit-image", "onnxruntime-gpu", "chardet", "matplotlib", "toml", "piexif", "rich", "timm", "ultralytics", "wget", "watchdog", "imageio-ffmpeg", "pickleshare", "insightface", "facexlib"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
subprocess.run(["pip", "install", "transformers>=4.46.3", "huggingface-hub>=0.26.5", "diffusers>=0.31.0", "accelerate"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# FIX BUG AIOHTTP/YARL (Le crash 'ValueError: Host') + Autres modules
print("   -> Correction bug connexion (aiohttp/yarl)...")
subprocess.run(["pip", "install", "--upgrade", "aiohttp", "yarl", "av", "einops", "torchsde", "kornia", "spandrel", "soundfile", "moviepy"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# --- 4. NETTOYAGE & INSTALLATION PuLID (lldacing) ---
print("\n🧹 [4/6] Installation de PuLID (Version lldacing)...")
# Nettoyage de TOUS les dossiers PuLID existants pour éviter les conflits
for folder in os.listdir(CUSTOM_NODES):
    if "pulid" in folder.lower():
        path = os.path.join(CUSTOM_NODES, folder)
        print(f"   🗑️ Suppression : {folder}")
        shutil.rmtree(path, ignore_errors=True)

# Clonage
print(f"   📥 Clonage de {PULID_DIR}...")
# !git clone https://github.com/lldacing/ComfyUI_PuLID_Flux_ll.git {PULID_DIR}

print("   📦 Installation requirements spécifiques...")
subprocess.run(["pip", "install", "-r", f"{PULID_DIR}/requirements.txt"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
subprocess.run(["pip", "install", "facenet-pytorch", "--no-deps"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# PATCH DU CODE (Fix 'latent_shapes')
print("   💉 Patching du code PuLID pour ComfyUI v0.3.76+...")
patched = False
for fname in ["pulid.py", "nodes.py", "pulid_flux.py"]:
    fpath = os.path.join(PULID_DIR, fname)
    if os.path.exists(fpath):
        with open(fpath, 'r') as f: content = f.read()
        # Regex : cherche la fonction et ajoute **kwargs
        pattern = r"(def\s+pulid_outer_sample_wrappers_with_override\s*\([^)]*?)(\)\s*:)"
        if re.search(pattern, content):
            new_content = re.sub(pattern, r"\1, **kwargs\2", content, count=1)
            with open(fpath, 'w') as f: f.write(new_content)
            print(f"   ✅ Patch appliqué sur {fname} !")
            patched = True
            break
        elif "**kwargs" in content and "pulid_outer_sample_wrappers_with_override" in content:
             print(f"   ℹ️ {fname} est déjà compatible.")
             patched = True

if not patched:
    print("   ⚠️ ATTENTION : Impossible de trouver la fonction à patcher.")

# --- 5. TÉLÉCHARGEMENT DES MODÈLES ---
print("\n📥 [5/6] Vérification des Modèles...")

# InsightFace AntelopeV2 (Miroir public Okaris)
antelope_dir = f"{COMFY_DIR}/models/insightface/models/antelopev2"
os.makedirs(antelope_dir, exist_ok=True)
files_antelope = ["1k3d68.onnx", "2d106det.onnx", "genderage.onnx", "glintr100.onnx", "scrfd_10g_bnkps.onnx"]
print("   -> Modèles InsightFace...")
for f in files_antelope:
    if not os.path.exists(f"{antelope_dir}/{f}"):
        subprocess.run(["aria2c", "-x", "16", "-s", "16", "-k", "1M", "-c", f"https://huggingface.co/okaris/antelopev2/resolve/main/{f}?download=true", "-d", antelope_dir, "-o", f], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# PuLID Model
pulid_flux_dir = f"{COMFY_DIR}/models/pulid"
os.makedirs(pulid_flux_dir, exist_ok=True)
if not os.path.exists(f"{pulid_flux_dir}/pulid_flux_v0.9.0.safetensors"):
    print("   -> Modèle PuLID Flux...")
    subprocess.run(["aria2c", "-x", "16", "-s", "16", "-k", "1M", "-c", "https://huggingface.co/guozinan/PuLID/resolve/main/pulid_flux_v0.9.0.safetensors", "-d", pulid_flux_dir, "-o", "pulid_flux_v0.9.0.safetensors"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Eva Clip
eva_dir = f"{COMFY_DIR}/models/clip"
if not os.path.exists(f"{eva_dir}/EVA02_CLIP_L_336_psz14_s6B.pt"):
    print("   -> Modèle Eva Clip...")
    subprocess.run(["aria2c", "-x", "16", "-s", "16", "-k", "1M", "-c", "https://huggingface.co/QuanSun/EVA-CLIP/resolve/main/EVA02_CLIP_L_336_psz14_s6B.pt", "-d", eva_dir, "-o", "EVA02_CLIP_L_336_psz14_s6B.pt"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# --- 6. LANCEMENT ---
print("\n🚀 [6/6] Lancement de ComfyUI...")

# Nettoyage WanVideo
if os.path.exists(f"{CUSTOM_NODES}/ComfyUI-wanBlockswap"):
    shutil.move(f"{CUSTOM_NODES}/ComfyUI-wanBlockswap", f"{CUSTOM_NODES}/ComfyUI-wanBlockswap_DISABLED")

# Script de lancement
run_script = """#!/bin/bash
cd /workspace/ComfyUI
echo "🔥 Lancement Optimisé (BF16)..."
python main.py --listen 0.0.0.0 --port 8188 --disable-auto-launch --fast
"""
with open("run_comfy.sh", "w") as f: f.write(run_script)
os.chmod("run_comfy.sh", 0o755)

print("✅ TERMINÉ. Le serveur démarre ci-dessous...")
# !./run_comfy.sh

# %%
# DÉMARRAGE STANDARD COMFYUI (CLEAN & SAFE)

import os
import subprocess
import sys

# --- CONFIGURATION ---
COMFY_DIR = "/workspace/ComfyUI"

print("🚀 DÉMARRAGE STANDARD (Sans modification de sécurité)...")

# 1. INSTALLATION OUTILS SYSTÈME (Indispensable pour la vidéo/téléchargement)
print("\n🔧 [1/4] Vérification outils système (ffmpeg, aria2)...")
subprocess.run(["apt-get", "update"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
subprocess.run(["apt-get", "install", "-y", "ffmpeg", "aria2"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# 2. DÉPENDANCES PYTHON CRITIQUES (InsightFace, etc.)
# On installe seulement ce qui manque souvent, sans tout casser.
print("\n📦 [2/4] Installation des librairies Python essentielles...")
pkgs = [
    "insightface", "onnxruntime-gpu", "facexlib", "opencv-python", "imageio-ffmpeg", # Pour le Face Swap/Analysis
    "huggingface_hub", "diffusers", "transformers" # Mises à jour standards
]
subprocess.run([sys.executable, "-m", "pip", "install"] + pkgs, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# 3. TÉLÉCHARGEMENT MODÈLES INSIGHTFACE (AntelopeV2)
# Ces fichiers sont requis pour ReActor, IPAdapter, PuLID, etc. On les garde car ce sont des ressources, pas de la config.
print("\n📥 [3/4] Vérification des modèles InsightFace (AntelopeV2)...")
antelope_dir = f"{COMFY_DIR}/models/insightface/models/antelopev2"
os.makedirs(antelope_dir, exist_ok=True)
files_antelope = ["1k3d68.onnx", "2d106det.onnx", "genderage.onnx", "glintr100.onnx", "scrfd_10g_bnkps.onnx"]

for f in files_antelope:
    if not os.path.exists(f"{antelope_dir}/{f}"):
        print(f"   ⬇️ Téléchargement : {f}")
        subprocess.run(["aria2c", "-x", "16", "-s", "16", "-k", "1M", "-c", f"https://huggingface.co/okaris/antelopev2/resolve/main/{f}?download=true", "-d", antelope_dir, "-o", f], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# 4. LANCEMENT STANDARD
print("\n🚀 [4/4] Lancement du serveur...")

# On crée un petit script shell pour lancer proprement
run_script = """#!/bin/bash
cd /workspace/ComfyUI
# --listen 0.0.0.0 est OBLIGATOIRE pour RunPod
# --disable-auto-launch évite d'essayer d'ouvrir un navigateur dans le terminal
python main.py --listen 0.0.0.0 --port 8188 --disable-auto-launch --fast
"""

with open("run_comfy.sh", "w") as f:
    f.write(run_script)
os.chmod("run_comfy.sh", 0o755)

print("✅ ComfyUI démarre maintenant. Surveillez les logs ci-dessous.")
# !./run_comfy.sh
