# %%
# %%bash
# # 1. Installation du moteur manquant
# apt-get update -y > /dev/null 2>&1
# apt-get install -y aria2 > /dev/null 2>&1
#
# # 2. On tue les processus fantômes que l'on voit dans ton ps aux
# pkill -9 -f manager_app.py
# pkill -9 aria2c
#
# # 3. On se place au bon endroit et on lance
# cd /workspace/model-manager
# nohup python manager_app.py > server.log 2>&1 &
#
# sleep 4
#
# # 4. On vérifie si ça écoute enfin
# echo "------------------------------------------------"
# if [ -f "server.log" ]; then
#     echo "📝 LOGS DU SERVEUR (Vérification des erreurs) :"
#     cat server.log
# else
#     echo "❌ Erreur critique : Le fichier de log n'a même pas été créé."
# fi
# Out:
# ------------------------------------------------
# 📝 LOGS DU SERVEUR (Vérification des erreurs) :
# 🚀 Manager Pro lancé (Mode Sécurisé).
